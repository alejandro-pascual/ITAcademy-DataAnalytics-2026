# %%
import pandas as pd

# %%
df = pd.read_excel('Datos/sprint8_complex.xlsx', skiprows=3)
df.rename(columns={'Unnamed: 0':'Id'}, inplace=True)

# %%
# » ¿Cuántas filas y columnas tiene el dataset?
# 1007 filas y 20 columnas.

# ¿Qué tipo de datos contiene cada columna?
# Id: int, nom: str, cognoms: str, DNI: str, país d'origen: str, ciutat: str, dia de naixement: float, mes de naixement: float, any de naixement: float, gènere: str, salari mensual: str, fills: object, no fills: object, grup professional: str, cÃ rrec: str, nombre_fills: float, te_cotxe: object, km_anuals: float,consum_mitja_l_100km: float, temperatura_mitjana_ciutat: float

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Id                          1007 non-null   int64
#  1   Nom                         1006 non-null   str
#  2   Cognoms                     1006 non-null   str
#  3   DNI                         1006 non-null   str
#  4   País d'origen               1006 non-null   str
#  5   Ciutat                      1006 non-null   str
#  6   Dia de Naixement            1006 non-null   float64
#  7   Mes de Naixement            1006 non-null   float64
#  8   Any de Naixement            1006 non-null   float64
#  9   Gènere                      966 non-null    str
#  10  Salari mensual              1006 non-null   str
#  11  Fills                       419 non-null    object
#  12  No Fills                    585 non-null    object
# ...

# %%
# ¿Hay filas duplicadas?
# No. Si se invierte el proceso, salen 1007 campos únicos, que son los totales, por lo que definitivamente no hay filas duplicadas.

dupe_counter = 0
for dupe in df.duplicated():
    if dupe == True:
        dupe_counter += 1

print(dupe_counter)
# Out:
# 0

# %%
# ¿Los datos parecen coherentes a primera vista?
# No. Hay gente que dice haber nacido el día 0 del mes 0, en el mes 99, en el año 3000, etc. También se pueden encontrar datos contradictorios, como "fills" marcado en True, pero "no fills" también marcado en True.

# ¿Detectas posibles problemas o inconsistencias evidentes?
#  Sí. La fecha de nacimiento está dividida en 3 campos distintos y guardada como float. El género está en diferentes formatos ('H' a veces es 'Home' y 'D' a veces es 'Dona' o 'F'). El salario mensual también está en diferentes formatos; con o sin coma, con símbolo de euros, escrito en letras. El campo de 'Fills' y el de 'No Fills' son ambos redundantes, ya que a partir del campo "Nombre_fills" (que no debería contener valores decimales), se pueden obtener estos valores sin haber de guardarlos en campos aparte. Los nombres de los campos tienen diferentes formatos también; algunos usan espacios y otros '_'. 

df.tail(1000)
# Out:
#         Id      Nom            Cognoms        DNI País d'origen  \
# 7        7   Carmen             LÃ³pez  47376585K       Espanya
# 8      540     Nora  Andersen Pedersen  37289414J       Noruega
# 9        9     Alba            GarcÃ­a  75181648S       Espanya
# 10      10    Joana       Torres DÃ­az  82772208R       Espanya
# 11      11  Guillem              Vidal  52169044F       Espanya
# ...    ...      ...                ...        ...           ...
# 1002  1002     Alba             MuÃ±oz  97954019T       Espanya
# 1003  1003  Claudia         Gil Ferrer  55297384F       Espanya
# 1004  1004    Oriol             Ferrer  52590001R       Espanya
# 1005  1005      NaN                NaN        NaN           NaN
# 1006  1006      ???                ###       XXXX        Narnia
#
#                           Ciutat  Dia de Naixement  Mes de Naixement  \
# 7                      Barcelona               8.0               9.0
# ...
