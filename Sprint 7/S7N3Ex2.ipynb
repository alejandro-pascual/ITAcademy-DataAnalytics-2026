# %%
f = open('Datos/historic partits.txt', 'r')

equipos = {
    
}

for bombo in f:
    splittedbombo = bombo.strip('\n').split('\t')
    # print(splittedbombo)
    equipos[splittedbombo[0]] = 1

print(equipos)

f.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 10
#       6
#       7 for bombo in f:
#       8     splittedbombo = bombo.strip('\n').split('\t')
#       9     # print(splittedbombo)
# ---> 10     equipos[splittedbombo[0]] += 1
#      11
#      12 print(equipos)
#      13
#
# KeyError: 'Manlleu'
